# %% [markdown]
# <a href="https://colab.research.google.com/github/AjMing/Pattern-EGCI463/blob/main/Week2/Example_IV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # More example on using Pandas and SKLEARN

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c835cd5-3707-4adc-8f40-2a73d0fa901c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c835cd5-3707-4adc-8f40-2a73d0fa901c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['calories.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df
# Out:
#       calories  test_score
# 0          201          76
# 1          142          72
# 2          397          84
# 3          294          79
# 4          334          76
# ...        ...         ...
# 1495       215          80
# 1496        31          49
# 1497       178          60
# 1498       238          68
# 1499       173          68
#
# [1500 rows x 2 columns]

# %%
df.describe()
# Out:
#           calories   test_score
# count  1500.000000  1500.000000
# mean    187.117333    70.016000
# std     117.009808    12.811863
# min       0.000000    42.000000
# 25%      82.750000    60.000000
# 50%     180.500000    70.000000
# 75%     288.000000    80.000000
# max     400.000000    98.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['calories'].plot(kind='hist', bins=20, title='calories')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['test_score'].plot(kind='hist', bins=20, title='test_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
df['calories'].plot(kind='hist', bins=20, title='calories')
# Out:
# <Axes: title={'center': 'calories'}, ylabel='Frequency'>

# %%
from matplotlib import pyplot as plt
_df_0['calories'].plot(kind='hist', bins=20, title='calories')
# Out:
# <Axes: title={'center': 'calories'}, ylabel='Frequency'>

# %%
new_df=(df-df.mean())/df.std()
print(new_df)
# Out:
#       calories  test_score
# 0     0.118645    0.467067
# 1    -0.385586    0.154856
# 2     1.793719    1.091488
# 3     0.913450    0.701225
# 4     1.255302    0.467067
# ...        ...         ...
# 1495  0.238293    0.779278
# 1496 -1.334224   -1.640355
# 1497 -0.077919   -0.781775
# 1498  0.434858   -0.157354
# 1499 -0.120651   -0.157354
#
# [1500 rows x 2 columns]

# %%
pd.options.display.float_format = "{:.1f}".format
new_df.describe()
# Out:
#        calories  test_score
# count    1500.0      1500.0
# mean       -0.0        -0.0
# std         1.0         1.0
# min        -1.6        -2.2
# 25%        -0.9        -0.8
# 50%        -0.1        -0.0
# 75%         0.9         0.8
# max         1.8         2.2

# %%
new_df2=(df-df.mean())/df.std()
print(new_df2)
# Out:
#       calories  test_score
# 0          0.1         0.5
# 1         -0.4         0.2
# 2          1.8         1.1
# 3          0.9         0.7
# 4          1.3         0.5
# ...        ...         ...
# 1495       0.2         0.8
# 1496      -1.3        -1.6
# 1497      -0.1        -0.8
# 1498       0.4        -0.2
# 1499      -0.1        -0.2
#
# [1500 rows x 2 columns]

# %%
new_df.describe()
# Out:
#        calories  test_score
# count    1500.0      1500.0
# mean       -0.0        -0.0
# std         1.0         1.0
# min        -1.6        -2.2
# 25%        -0.9        -0.8
# 50%        -0.1        -0.0
# 75%         0.9         0.8
# max         1.8         2.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['calories'].plot(kind='hist', bins=20, title='calories')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['test_score'].plot(kind='hist', bins=20, title='test_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# # Try with the result of MinMax **Scaler**

# %%
import sklearn.preprocessing as preprocessing
scaler = preprocessing.MinMaxScaler()

# %% [markdown]
# Try to identify and remove

# %%
 df_Q= pd.DataFrame(preprocessing.QuantileTransformer(
            output_distribution="uniform", random_state=42
        ).fit_transform(df))

# %%
df_R= pd.DataFrame(preprocessing.RobustScaler().fit_transform(df))
