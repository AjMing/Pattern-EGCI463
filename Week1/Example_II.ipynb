# %% [markdown]
# <a href="https://colab.research.google.com/github/AjMing/Pattern-EGCI463/blob/main/Example_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Data

# %%
import pandas as pd
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
df1 = pd.read_csv(url,header=None)

# %%
df1
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-692f7479-b98d-4090-b554-263d8f42f383" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-692f7479-b98d-4090-b554-263d8f42f383">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['Iris.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df2
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
print(df2[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-af2ea6afbe34> in <module>()
# ----> 1 print(df2[1])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 1

# %%
print(df2.iloc[1])
# Out:
# Id                         2
# SepalLengthCm            4.9
# SepalWidthCm               3
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 1, dtype: object

# %%
print(df2.iloc[1][5])
# Out:
# Iris-setosa

# %%
print(df2['SepalLengthCm'])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
print(df2.iloc[1]['SepalLengthCm'])
print(df2.loc[1]['SepalLengthCm'])
# Out:
# 4.9
# 4.9

# %%
import numpy as np
data=np.array([[' ', 'C1','C2'], ['R1',1,2], ['R2',3,4],])
df=pd.DataFrame(data=data[1:,1:],
                       index=data[1:,0],
                       columns=data[0,1:])
print(df[0:2])
print(df['C1'])
print(df.shape)
df.describe()
# Out:
#    C1 C2
# R1  1  2
# R2  3  4
# R1    1
# R2    3
# Name: C1, dtype: object
# (2, 2)
#        C1 C2
# count   2  2
# unique  2  2
# top     1  2
# freq    1  1

# %%
df['C3']=''
df
# Out:
#    C1 C2 C3  C4
# R1  1  2      5
# R2  3  4      6

# %%
df['C4']=[5,6]
df
# Out:
#    C1 C2 C3  C4
# R1  1  2      5
# R2  3  4      6

# %%
# Out:
#    C1 C2  C4
# R1  1  2   5
# R2  3  4   6

# %% [markdown]
# **TASK 1:**
# *Import* ‘iris’ data (.csv format)
#   Display
#
# 1.   Display the last 10 elements
# 2.   Copy the second column(width) to a list
# 3.   Display the first 10 elements
# 4.   Drop the last column
# 5.   Write a function to print only the specified range (of the remaing column)

# %% [markdown]
# **TASK2**
# 1.   Create a new column called Species_label
# 2.   change name in Species to 0,1,2 in Species_label
# 3.   Print mean,var group by Species label

# %% [markdown]
# **TASK3**
#
#
# 1.   USE test.csv
# 2.   Create a 'sum score' column
# 3.   Plot (scatter) by id based on a sum
